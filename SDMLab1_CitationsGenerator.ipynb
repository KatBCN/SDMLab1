# %% [markdown]
# <a href="https://colab.research.google.com/github/KatBCN/SDMLab1/blob/main/SDMLab1_CitationsGenerator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Citations
#
# Implement a data generator to assign citation relationships among papers.
#
# Idea for citation code plan:
#
# Assume that one-third of papers in our database cite another paper in our database. (Other papers would likely be citing papers outside of our database, but we won't be concerned about modeling those relationships)
#
# 1. Create citation dataframe as a sample of papers dataframe (for example 0.3)
# 2. Add column for citation
# 3. Using a random generator to choose a paper published previously to cite.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# A cypher query was used to export a .csv file of papers that are already in the graph database.
#
# - All papers were included whether they were published as part of a journal or a conference.
#
# - The column "volumeEdition" should be interpreted as the title of the journal volume or conference edition where the paper was published.
#
# - The column "journalConference" should be interpreted as the title of the conference or journal where the paper was published.
#
# Cypher Query:
# ```
# MATCH(author:Author)-[:WROTE {role:"corresponding"}]->(paper:Paper)-[:PUBLISHED_IN]->(volumeEdition)-[]->(journalConference)
# RETURN author.name as author, paper.title as title, volumeEdition.title as volumeEdition, volumeEdition.year as year, journalConference.title as journalConference
# ```

# %%
# path where papers.csv is stored
path = "https://raw.githubusercontent.com/KatBCN/SDMLab1/main/papers.csv"

# %%
papers = pd.read_csv(path)
papers.head()
# Out:
#                author                                              title  \
# 0       Kun Wang 0005  Robust Big Data Analytics for Electricity Pric...
# 1  Hongjian Wang 0002  Non-Stationary Model for Crime Rate Inference ...
# 2        Binfeng Wang  Noise-Resistant Statistical Traffic Classifica...
# 3       Zheng Xu 0001  Multi-Modal Description of Public Safety Event...
# 4      Zheng Yan 0002  Heterogeneous Data Storage Management with Ded...
#
#                   volumeEdition  year     journalConference
# 0  IEEE Trans. Big Data,vol.5-1  2019  IEEE Trans. Big Data
# 1  IEEE Trans. Big Data,vol.5-2  2019  IEEE Trans. Big Data
# 2  IEEE Trans. Big Data,vol.5-4  2019  IEEE Trans. Big Data
# 3  IEEE Trans. Big Data,vol.5-4  2019  IEEE Trans. Big Data
# 4  IEEE Trans. Big Data,vol.5-3  2019  IEEE Trans. Big Data

# %%
papers.shape
# Out:
# (1520, 5)

# %%
papers.describe(include='all')
# Out:
#                author                                              title  \
# count            1520                                               1520
# unique           1364                                               1505
# top     Chae-Gyun Lim  Comments to Jean-Claude Burgelman's article Po...
# freq                8                                                  6
# mean              NaN                                                NaN
# std               NaN                                                NaN
# min               NaN                                                NaN
# 25%               NaN                                                NaN
# 50%               NaN                                                NaN
# 75%               NaN                                                NaN
# max               NaN                                                NaN
#
#        volumeEdition         year journalConference
# count           1520  1520.000000              1520
# unique            77          NaN                 6
# top     BigComp-2018          NaN           BigComp
# freq             139          NaN               755
# mean             NaN  2018.408553               NaN
# std              NaN     2.108525               NaN
# min              NaN  2014.000000               NaN
# 25%              NaN  2017.000000               NaN
# 50%              NaN  2019.000000               NaN
# 75%              NaN  2020.000000               NaN
# max              NaN  2022.000000               NaN

# %%
papers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1520 entries, 0 to 1519
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   author             1520 non-null   object
#  1   title              1520 non-null   object
#  2   volumeEdition      1520 non-null   object
#  3   year               1520 non-null   int64
#  4   journalConference  1520 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 59.5+ KB

# %% [markdown]
# First, we need to sort the papers by year, in ascending order. The sorted order can be used as an assumption of the order of publication.

# %%
df = papers.sort_values(by=['year','journalConference','volumeEdition','title','author'], ascending=True).copy().reset_index()

# %%
df.head(10)
# Out:
#    index             author  \
# 0    332      Brian Schmidt
# 1    326    Vassilis Kolias
# 2    322     Jong Hoon Ahnn
# 3    334   Jianwu Wang 0001
# 4    333   Blesson Varghese
# 5    335  Justin M. Wozniak
# 6    323      Pablo Fuentes
# 7    329   Raghavendra Kune
# 8    327       Jared Koontz
# 9    328       Eileen Kuehn
#
#                                                title volumeEdition  year  \
# 0  A Biologically-Inspired Approach to Network Tr...      BDC-2014  2014
# 1  A Covering Classification Rule Induction Appro...      BDC-2014  2014
# 2  A Practical Approach to Scalable Big Data Comp...      BDC-2014  2014
# 3  A Scalable Data Science Workflow Approach for ...      BDC-2014  2014
# 4  Are Clouds Ready to Accelerate Ad Hoc Financia...      BDC-2014  2014
# 5  Big Data Staging with MPI-IO for Interactive X...      BDC-2014  2014
# 6  Characterizing the Communication Demands of th...      BDC-2014  2014
# 7  Genetic Algorithm Based Data-Aware Group Sched...      BDC-2014  2014
# 8  GeoLens - Enabling Interactive Visual Analytic...      BDC-2014  2014
# 9  Monitoring Data Streams at Process Level in Sc...      BDC-2014  2014
#
#   journalConference
# 0               BDC
# 1               BDC
# 2               BDC
# 3               BDC
# 4               BDC
# 5               BDC
# 6               BDC
# 7               BDC
# 8               BDC
# 9               BDC

# %%
df.tail(10)
# Out:
#       index               author  \
# 1510    927       Qingchen Zhang
# 1511    921             Hu Xiong
# 1512    920             Sijie Wu
# 1513    909  Hourieh Khalajzadeh
# 1514    907     Chengqiang Huang
# 1515    917              Ziyi Su
# 1516    912         Chuishi Meng
# 1517    922            Qichao Xu
# 1518    916       Jian Shen 0001
# 1519    918            Bing Tang
#
#                                                   title  \
# 1510  PPHOPCM - Privacy-Preserving High-Order Possib...
# 1511  Revocable Identity-Based Access Control for Bi...
# 1512  Shadow - Exploiting the Power of Choice for Ef...
# 1513  Survey and Analysis of Current End-User Data A...
# 1514  Time Series Anomaly Detection for Trustworthy ...
# 1515  Toward Architectural and Protocol-Level Founda...
# 1516  Towards the Inference of Travel Purpose with H...
# 1517  Trust Based Incentive Scheme to Allocate Big D...
# 1518  Trustworthiness Evaluation-Based Routing Proto...
# 1519  WukaStore - Scalable, Configurable and Reliabl...
#
#                      volumeEdition  year     journalConference
# 1510  IEEE Trans. Big Data,vol.8-1  2022  IEEE Trans. Big Data
# 1511  IEEE Trans. Big Data,vol.8-1  2022  IEEE Trans. Big Data
# 1512  IEEE Trans. Big Data,vol.8-1  2022  IEEE Trans. Big Data
# 1513  IEEE Trans. Big Data,vol.8-1  2022  IEEE Trans. Big Data
# 1514  IEEE Trans. Big Data,vol.8-1  2022  IEEE Trans. Big Data
# 1515  IEEE Trans. Big Data,vol.8-1  2022  IEEE Trans. Big Data
# 1516  IEEE Trans. Big Data,vol.8-1  2022  IEEE Trans. Big Data
# 1517  IEEE Trans. Big Data,vol.8-1  2022  IEEE Trans. Big Data
# 1518  IEEE Trans. Big Data,vol.8-1  2022  IEEE Trans. Big Data
# 1519  IEEE Trans. Big Data,vol.8-1  2022  IEEE Trans. Big Data

# %% [markdown]
# Idea for citation code plan:
#
# Assume that one-third of papers in our database cite another paper in our database. (Other papers would likely be citing papers outside of our database, but we won't be concerned about modeling those relationships)
#
# 1. Create citation dataframe as a sample of papers dataframe (for example 0.3)
# 2. Add column for citation
# 3. Using a random generator to choose a paper published previously to cite.

# %%
np.random.seed(42)
